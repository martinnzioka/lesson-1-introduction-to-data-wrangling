# %% [markdown]
# # Data Wrangling Template

# %% [markdown]
# ## Gather

# %% [markdown]
# ### Unzipping Data Source

# %%
# Uploading to Kaggle results in automatic extraction of the zip file, 
# Use this cell and the next, if you are running this notebook in a ``Jupyter NoteBook [Locally/Cloud{Hosted}]``

# uncomment the following code if you are running this notebook in a Jupyter NoteBook [Locally/Cloud{Hosted}]
# import zipfile

# %%
# uncomment the following code if you are running this notebook in a Jupyter NoteBook [Locally/Cloud{Hosted}]

# with zipfile.ZipFile('../input/armenian-online-job-postings.zip', mode='r') as myzip:
#     myzip.extractall()

# %% [markdown]
# ### Importing Data

# %% [markdown]
# ## Assess

# %% [markdown]
# ## Clean

# %% [markdown]
# #### Define

# %% [markdown]
# #### Code

# %% [markdown]
# #### Test
